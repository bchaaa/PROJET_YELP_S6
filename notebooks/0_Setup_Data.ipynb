# %% [markdown]
# # Etape 0 : Preparation et Chargement des Donnees
# Ce notebook permet de verifier que les bibliotheques sont bien installees et que le module src est accessible.

# %%
import sys
import os
# Ajout du dossier parent au path pour pouvoir importer le dossier src
sys.path.append(os.path.abspath('..'))
from src.data_loader import load_yelp_sample
print('Importation du module src reussie.')
# Out:
# Importation du module src reussie.

# %%
# Test de chargement d'un petit echantillon pour verifier les chemins
df = load_yelp_sample('../data/raw/review.json', n_rows=100)
print(f'Le chargement fonctionne. Taille du dataframe : {df.shape}')
# Out:
# Chargement de 100 lignes depuis ../data/raw/review.json...
# Le chargement fonctionne. Taille du dataframe : (100, 9)
